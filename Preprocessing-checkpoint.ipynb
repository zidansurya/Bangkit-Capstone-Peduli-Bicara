# %%
pip install keras
# Out:
# Requirement already satisfied: keras in d:\software\anaconda\lib\site-packages (2.9.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in d:\software\anaconda\lib\site-packages (2.9.1)
# Requirement already satisfied: astunparse>=1.6.0 in d:\software\anaconda\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in d:\software\anaconda\lib\site-packages (from tensorflow) (14.0.1)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\software\anaconda\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in d:\software\anaconda\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\software\anaconda\lib\site-packages (from tensorflow) (3.10.0.2)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in d:\software\anaconda\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\software\anaconda\lib\site-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: six>=1.12.0 in d:\software\anaconda\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in d:\software\anaconda\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\software\anaconda\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in d:\software\anaconda\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: setuptools in d:\software\anaconda\lib\site-packages (from tensorflow) (58.0.4)
# Requirement already satisfied: packaging in d:\software\anaconda\lib\site-packages (from tensorflow) (21.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in d:\software\anaconda\lib\site-packages (from tensorflow) (3.19.4)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: h5py>=2.9.0 in d:\software\anaconda\lib\site-packages (from tensorflow) (3.2.1)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in d:\software\anaconda\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in d:\software\anaconda\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: numpy>=1.20 in d:\software\anaconda\lib\site-packages (from tensorflow) (1.20.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\software\anaconda\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in d:\software\anaconda\lib\site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: absl-py>=1.0.0 in d:\software\anaconda\lib\site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\software\anaconda\lib\site-packages (from tensorflow) (1.46.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\software\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in d:\software\anaconda\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.6.6)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\software\anaconda\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.0.2)
# Requirement already satisfied: markdown>=2.6.8 in d:\software\anaconda\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.3.7)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in d:\software\anaconda\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\software\anaconda\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.26.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in d:\software\anaconda\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
#
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in d:\software\anaconda\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\software\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\software\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\software\anaconda\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (5.1.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\software\anaconda\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in d:\software\anaconda\lib\site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in d:\software\anaconda\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\software\anaconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in d:\software\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\software\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\software\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in d:\software\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\software\anaconda\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\software\anaconda\lib\site-packages (from packaging->tensorflow) (3.0.4)

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import tensorflow as tf
import pathlib
import os
import glob
import zipfile

from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras import layers
from tensorflow.keras import models
from IPython import display

# %%
seed = 42
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
with zipfile.ZipFile('dataset_dikit.zip','r') as zip_ref:
    zip_ref.extractall(r'C:\Users\Beastbook\test')

# %%
data_dir = pathlib.Path('C:\\Users\\Beastbook\\test\\dataset dikit')
commands = np.array(tf.io.gfile.listdir(str(data_dir)))
print('Commands:', commands)
# Out:
# Commands: ['Anggur' 'Anjing' 'Apel' 'Ayam' 'Ayam goreng' 'Bebek' 'Buaya' 'Bubur']

# %%
filenames = tf.io.gfile.glob(str(data_dir) + '/*/*')
filenames = tf.random.shuffle(filenames)
num_samples = len(filenames)
print("Number of total samples:", num_samples)
print("Number of sample per labes:", len(tf.io.gfile.listdir(str(data_dir/commands[0]))))
print("Example file tentor:", filenames[0])
# Out:
# Number of total samples: 96
# Number of sample per labes: 12
# Example file tentor: tf.Tensor(b'C:\\Users\\Beastbook\\test\\dataset dikit\\Ayam\\Ayam2.wav', shape=(), dtype=string)

# %%
train_files = filenames[:12]
val_files = filenames[12: 12 + 10]
test_files = filenames[-12:]

print("Training set size", len(train_files))
print("Validation set size", len(val_files))
print("Test set size", len(test_files))
# Out:
# Training set size 12
# Validation set size 10
# Test set size 12

# %%
def decode_audio(audio_binary):
  audio, _ = tf.audio.decode_wav(audio_binary, desired_channels=1)
  return tf.squeeze(audio, axis=-1)

# %%
def get_label(file_path):
  parts = tf.strings.split(file_path, os.path.sep)
  return parts[-2]

# %%
def get_waveform_and_label(file_path):
    label = get_label(file_path)
    audio_binary = tf.io.read_file(file_path)
    waveform = decode_audio(audio_binary)

    return waveform, label

# %%
def get_spectrogram(waveform):
    # Padding for files with less than 16000 samples
    zero_padding = tf.zeros([16000] - tf.shape(waveform), dtype=tf.float32)
    # Concatenate audio with padding so that all audio clips will be of the same length
    waveform = tf.cast(waveform, tf.float32)
    equal_length = tf.concat([waveform, zero_padding], 0)
    spectrogram = tf.signal.stft(
        equal_length, frame_length=255, frame_step=128)
    spectrogram = tf.abs(spectrogram)

    return spectrogram

# %%
def get_spectrogram_and_label_id(audio, label):
    spectrogram = get_spectrogram(audio)
    spectrogram = tf.expand_dims(spectrogram, -1)
    label_id = tf.argmax(label == commands)

    return spectrogram, label_id

# %%
def preprocess_dataset(files, autotune, commands):
    # Creates the dataset
    files_ds = tf.data.Dataset.from_tensor_slices(files)

    # Matches audio files with correct labels
    output_ds = files_ds.map(get_waveform_and_label,
                             num_parallel_calls=autotune)
    # Matches audio file images to the correct labels
    output_ds = output_ds.map(
        get_spectrogram_and_label_id,  
        num_parallel_calls=autotune)

    return output_ds

# %%
AUTOTUNE = tf.data.AUTOTUNE

files_ds = tf.data.Dataset.from_tensor_slices(train_files)

waveform_ds = files_ds.map(
    map_func=get_waveform_and_label,
    num_parallel_calls=AUTOTUNE)

# %%
# Get the converted audio files for training the model
files_ds = tf.data.Dataset.from_tensor_slices(train_files)
waveform_ds = files_ds.map(
    get_waveform_and_label, num_parallel_calls=autotune)
spectrogram_ds = waveform_ds.map(
    get_spectrogram_and_label_id, num_parallel_calls=autotune)

# %%
train_ds = preprocess_dataset(train_files, autotune, commands)
validation_ds = preprocess_dataset(val_files, autotune, commands)
test_ds = preprocess_dataset(test_files, autotune, commands)

# %%
batch_size = 64
train_ds = train_ds.batch(batch_size)
validation_ds = validation_ds.batch(batch_size)

# %%
train_ds = train_ds.cache().prefetch(autotune)
validation_ds = validation_ds.cache().prefetch(autotune)

# %%
rows = 3
cols = 3
n = rows * cols
fig, axes = plt.subplots(rows, cols, figsize=(12, 12))

for i, (audio, label) in enumerate(waveform_ds.take(n)):
  r = i // cols
  c = i % cols
  ax = axes[r][c]
  ax.plot(audio.numpy())
  ax.set_yticks(np.arange(-1.2, 1.2, 0.2))
  label = label.numpy().decode('utf-8')
  ax.set_title(label)

plt.show()

# %%
def get_spectrogram(waveform):
  # Zero-padding for an audio waveform with less than 16,000 samples.
  input_len = 16000
  waveform = waveform[:input_len]
  zero_padding = tf.zeros(
      [16000] - tf.shape(waveform),
      dtype=tf.float32)
  # Cast the waveform tensors' dtype to float32.
  waveform = tf.cast(waveform, dtype=tf.float32)
  # Concatenate the waveform with `zero_padding`, which ensures all audio
  # clips are of the same length.
  equal_length = tf.concat([waveform, zero_padding], 0)
  # Convert the waveform to a spectrogram via a STFT.
  spectrogram = tf.signal.stft(
      equal_length, frame_length=255, frame_step=128)
  # Obtain the magnitude of the STFT.
  spectrogram = tf.abs(spectrogram)
  # Add a `channels` dimension, so that the spectrogram can be used
  # as image-like input data with convolution layers (which expect
  # shape (`batch_size`, `height`, `width`, `channels`).
  spectrogram = spectrogram[..., tf.newaxis]
  return spectrogram

# %%
for waveform, label in waveform_ds.take(1):
  label = label.numpy().decode('utf-8')
  spectrogram = get_spectrogram(waveform)

print('Label:', label)
print('Waveform shape:', waveform.shape)
print('Spectrogram shape:', spectrogram.shape)
print('Audio playback')
display.display(display.Audio(waveform, rate=16000))
# Out:
# Label: Bubur
# Waveform shape: (72072,)
# Spectrogram shape: (124, 129, 1)
# Audio playback
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
